# %%
import numpy as np
import pandas as pd
import pickle
import joblib
import math
from tqdm import tqdm

import xgboost as xgb
import lightgbm as lgbm
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', 1000)

# %%
train = pd.read_csv('./data/train/train.csv')
print(train.shape)
train.head(1)
# Out:
# (52560, 9)
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0

# %% [markdown]
# ### sunrise sunset sunny 변수 추가

# %%
def time_minute(data):
    hour = data['Hour']
    if data['Minute'] == 0:
        minute = 0
    else:
        minute = 0.5
    
    return hour + minute

# %%
ghi = train.iloc[np.where(train['DHI'] + train['DNI'] >0)[0]].reset_index(drop=True)
ghi['time_float'] = [time_minute(ghi.iloc[i]) for i in range(len(ghi.index))]

train_by_day = pd.DataFrame(ghi.groupby(['Day'])['time_float'].min()).reset_index()
train_by_day.rename(columns = {'time_float': 'sunrise'}, inplace=True)
train_by_day['sunset'] = pd.DataFrame(ghi.groupby(['Day'])['time_float'].max())['time_float']
train_by_day['sunny'] = train_by_day['sunset'] - train_by_day['sunrise']

# %%
print(train_by_day.shape)
train_by_day.head(1)

# %% [markdown]
# ### date, month 변수 추가

# %%
train_by_day[train_by_day['sunny'] == 8] # 마지막 동지를 2018년 동지, 12월22일로 지정 (1월1일부터 데이터 맞음)
# Out:
#        Day  sunrise  sunset  sunny
# 356    356      8.0    16.0    8.0
# 721    721      8.0    16.0    8.0
# 1086  1086      8.0    16.0    8.0

# %%
train_by_day['date'] = train_by_day['Day']%365 # 365일 기준 날짜 생성

# %%
def day_to_month(date):
    
    if date < 31 :
        return 0
    elif date < 59 :
        return 1
    elif date < 90 :
        return 2
    elif date < 120 :
        return 3
    elif date < 151 :
        return 4
    elif date < 181 :
        return 5
    elif date < 212 :
        return 6
    elif date < 243 :
        return 7
    elif date < 273 :
        return 8
    elif date < 304 :
        return 9
    elif date < 334 :
        return 10
    else :
        return 11

# %%
train_by_day['month'] = [day_to_month(i) for i in train_by_day['date']]
train_by_day.head(1)
# Out:
#    Day  sunrise  sunset  sunny  date  month
# 0    0      8.0    16.5    8.5     0      0

# %% [markdown]
# ### 기타 변수 추가 (day 기준으로 변환)

# %%
train_by_day['temp_diff'] = pd.DataFrame(pd.DataFrame(train.groupby(['Day'])['T'].max()) - pd.DataFrame(train.groupby(['Day'])['T'].min()))['T']
train_by_day['T_mean'] = pd.DataFrame(train.groupby(['Day'])['T'].mean())['T']
train_by_day['DHI_mean'] = pd.DataFrame(train.groupby(['Day'])['DHI'].mean())['DHI']
train_by_day['DNI_mean'] = pd.DataFrame(train.groupby(['Day'])['DNI'].mean())['DNI']
train_by_day['WS_mean'] = pd.DataFrame(train.groupby(['Day'])['WS'].mean())['WS']
train_by_day['RH_mean'] = pd.DataFrame(train.groupby(['Day'])['RH'].mean())['RH']
train_by_day['TARGET_mean'] = pd.DataFrame(train.groupby(['Day'])['TARGET'].mean())['TARGET']

# %%
train_by_day
# Out:
#        Day  sunrise  sunset  sunny  date  month    T_mean   DHI_mean  \
# 0        0      8.0    16.5    8.5     0      0 -7.979167  44.937500
# 1        1      8.0    16.5    8.5     1      0 -6.312500  18.604167
# 2        2      8.0    16.5    8.5     2      0 -6.479167  28.937500
# 3        3      8.0    16.5    8.5     3      0 -5.687500  39.312500
# 4        4      8.0    16.5    8.5     4      0  0.854167  44.125000
# ...    ...      ...     ...    ...   ...    ...       ...        ...
# 1090  1090      8.0    16.5    8.5   360     11 -0.895833  18.729167
# 1091  1091      8.0    16.5    8.5   361     11  0.854167  29.833333
# 1092  1092      8.0    16.5    8.5   362     11  2.187500  34.562500
# 1093  1093      8.0    16.5    8.5   363     11  1.687500  16.708333
# 1094  1094      8.0    16.5    8.5   364     11 -2.708333  35.833333
#
#         DNI_mean   WS_mean    RH_mean  TARGET_mean  temp_diff
# 0      78.708333  1.929167  70.329375     6.520751          9
# 1     295.187500  1.718750  74.231250    11.025184         14
# 2      24.645833  2.470833  76.275000     3.165478         13
# 3      66.979167  2.279167  65.695208     5.810807         15
# 4      22.500000  3.995833  73.361042     4.817273         11
# ...          ...       ...        ...          ...        ...
# 1090  306.437500  2.810417  57.857500    11.261230         14
# 1091  206.583333  1.970833  55.269792     9.349126          8
# 1092  171.291667  3.368750  49.227292     8.875729         11
# 1093  309.812500  3.252083  49.218333    11.114171         14
# 1094  181.166667  2.137500  62.066042     8.710275          6
#
# [1095 rows x 13 columns]

# %% [markdown]
# ### GHI, dew, cloudy 추가

# %%
train[:3]
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET
# 0    0     0       0    0    0  1.5  69.08 -12     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0

# %%
# GHI -----------------------------------------------------------------------------
train['GHI'] = train['DHI'] + train['DNI']

# dew -----------------------------------------------------------------------------
def dewpoint(rh, t) :
    gamma = math.log(rh/100) + 17.62*t/(243.12+t)
    dew = (243.12*gamma)/(17.62-gamma)
    return dew

train['dew'] = [dewpoint(train['RH'][i], train['T'][i]) for i in range(len(train))]

# cloudy -----------------------------------------------------------------------------
train['cloudy'] = train['DHI']/(train['DNI']+0.1)

# %%
train[:3]
# Out:
#    Day  Hour  Minute  DHI  DNI   WS     RH   T  TARGET  GHI        dew  cloudy
# 0    0     0       0    0    0  1.5  69.08 -12     0.0    0 -16.522271     0.0
# 1    0     0      30    0    0  1.5  69.06 -12     0.0    0 -16.525742     0.0
# 2    0     1       0    0    0  1.6  71.78 -12     0.0    0 -16.061776     0.0

# %%
train_by_day['GHI_mean'] = pd.DataFrame(train.groupby(['Day'])['GHI'].mean())['GHI']
train_by_day['dew_mean'] = pd.DataFrame(train.groupby(['Day'])['dew'].mean())['dew']
train_by_day['cloudy_mean'] = pd.DataFrame(train.groupby(['Day'])['cloudy'].mean())['cloudy']

# %%
train_by_day
# Out:
#        Day  sunrise  sunset  sunny  date  month    T_mean   DHI_mean  \
# 0        0      8.0    16.5    8.5     0      0 -7.979167  44.937500
# 1        1      8.0    16.5    8.5     1      0 -6.312500  18.604167
# 2        2      8.0    16.5    8.5     2      0 -6.479167  28.937500
# 3        3      8.0    16.5    8.5     3      0 -5.687500  39.312500
# 4        4      8.0    16.5    8.5     4      0  0.854167  44.125000
# ...    ...      ...     ...    ...   ...    ...       ...        ...
# 1090  1090      8.0    16.5    8.5   360     11 -0.895833  18.729167
# 1091  1091      8.0    16.5    8.5   361     11  0.854167  29.833333
# 1092  1092      8.0    16.5    8.5   362     11  2.187500  34.562500
# 1093  1093      8.0    16.5    8.5   363     11  1.687500  16.708333
# 1094  1094      8.0    16.5    8.5   364     11 -2.708333  35.833333
#
#         DNI_mean   WS_mean    RH_mean  TARGET_mean  temp_diff    GHI_mean  \
# 0      78.708333  1.929167  70.329375     6.520751          9  123.645833
# 1     295.187500  1.718750  74.231250    11.025184         14  313.791667
# 2      24.645833  2.470833  76.275000     3.165478         13   53.583333
# 3      66.979167  2.279167  65.695208     5.810807         15  106.291667
# 4      22.500000  3.995833  73.361042     4.817273         11   66.625000
# ...          ...       ...        ...          ...        ...         ...
# 1090  306.437500  2.810417  57.857500    11.261230         14  325.166667
# 1091  206.583333  1.970833  55.269792     9.349126          8  236.416667
# 1092  171.291667  3.368750  49.227292     8.875729         11  205.854167
# 1093  309.812500  3.252083  49.218333    11.114171         14  326.520833
# 1094  181.166667  2.137500  62.066042     8.710275          6  217.000000
#
#        dew_mean  cloudy_mean
# 0    -12.552381    16.837523
# 1    -10.362553     4.812806
# 2    -10.028902   145.157079
# 3    -11.207274    51.440077
# 4     -3.405437    99.004255
# ...         ...          ...
# 1090  -8.348487     0.022263
# 1091  -7.286454     3.383069
# 1092  -7.465153     3.202771
# 1093  -8.257195     0.019912
# 1094  -9.277635     0.250196
#
# [1095 rows x 16 columns]

# %% [markdown]
# ### month 예측 모델 생성

# %%
X = train_by_day.drop(['Day', 'date', 'month', 'cloudy_mean'], axis=1)
y = train_by_day['month']

SEED = 777
TEST_RATIO = 0.2

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=TEST_RATIO, random_state=SEED)

# %%
len(X_train), len(X_val)
# Out:
# (876, 219)

# %% [markdown]
# #### XGB

# %%
model = xgb.XGBClassifier(use_label_encoder=False, objective='multi:softmax', eval_metric='mlogloss', n_estimators=1000, random_state=SEED)
model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds=200)
# Out:
# [13:12:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { use_label_encoder } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-mlogloss:1.63318
# Will train until validation_0-mlogloss hasn't improved in 200 rounds.
# [1]	validation_0-mlogloss:1.29301
# [2]	validation_0-mlogloss:1.07842
# [3]	validation_0-mlogloss:0.93635
# [4]	validation_0-mlogloss:0.82380
# [5]	validation_0-mlogloss:0.74052
# [6]	validation_0-mlogloss:0.67853
# [7]	validation_0-mlogloss:0.63132
# [8]	validation_0-mlogloss:0.59391
# [9]	validation_0-mlogloss:0.56118
# [10]	validation_0-mlogloss:0.54015
# [11]	validation_0-mlogloss:0.52212
# [12]	validation_0-mlogloss:0.50940
# [13]	validation_0-mlogloss:0.49943
# [14]	validation_0-mlogloss:0.49069
# [15]	validation_0-mlogloss:0.48179
# [16]	validation_0-mlogloss:0.47265
# [17]	validation_0-mlogloss:0.46566
# [18]	validation_0-mlogloss:0.46229
# [19]	validation_0-mlogloss:0.45472
# [20]	validation_0-mlogloss:0.45321
# [21]	validation_0-mlogloss:0.45124
# [22]	validation_0-mlogloss:0.45160
# [23]	validation_0-mlogloss:0.45179
# [24]	validation_0-mlogloss:0.45323
# [25]	validation_0-mlogloss:0.45346
# [26]	validation_0-mlogloss:0.45300
# [27]	validation_0-mlogloss:0.45513
# [28]	validation_0-mlogloss:0.45403
# [29]	validation_0-mlogloss:0.45159
# [30]	validation_0-mlogloss:0.45477
# [31]	validation_0-mlogloss:0.45483
# [32]	validation_0-mlogloss:0.45326
# [33]	validation_0-mlogloss:0.45481
# [34]	validation_0-mlogloss:0.45650
# [35]	validation_0-mlogloss:0.45840
# [36]	validation_0-mlogloss:0.45884
# [37]	validation_0-mlogloss:0.46193
# [38]	validation_0-mlogloss:0.46067
# [39]	validation_0-mlogloss:0.46080
# [40]	validation_0-mlogloss:0.46065
# [41]	validation_0-mlogloss:0.46137
# [42]	validation_0-mlogloss:0.46306
# [43]	validation_0-mlogloss:0.46278
# [44]	validation_0-mlogloss:0.46390
# [45]	validation_0-mlogloss:0.46532
# [46]	validation_0-mlogloss:0.46495
# [47]	validation_0-mlogloss:0.46623
# [48]	validation_0-mlogloss:0.46892
# [49]	validation_0-mlogloss:0.46971
# [50]	validation_0-mlogloss:0.47021
# [51]	validation_0-mlogloss:0.47075
# [52]	validation_0-mlogloss:0.47145
# [53]	validation_0-mlogloss:0.47302
# [54]	validation_0-mlogloss:0.47565
# [55]	validation_0-mlogloss:0.47546
# [56]	validation_0-mlogloss:0.47589
# [57]	validation_0-mlogloss:0.47713
# [58]	validation_0-mlogloss:0.47803
# [59]	validation_0-mlogloss:0.47876
# [60]	validation_0-mlogloss:0.47965
# [61]	validation_0-mlogloss:0.48009
# [62]	validation_0-mlogloss:0.48110
# [63]	validation_0-mlogloss:0.48122
# [64]	validation_0-mlogloss:0.48308
# [65]	validation_0-mlogloss:0.48336
# [66]	validation_0-mlogloss:0.48397
# [67]	validation_0-mlogloss:0.48475
# [68]	validation_0-mlogloss:0.48408
# [69]	validation_0-mlogloss:0.48457
# [70]	validation_0-mlogloss:0.48489
# [71]	validation_0-mlogloss:0.48519
# [72]	validation_0-mlogloss:0.48637
# [73]	validation_0-mlogloss:0.48703
# [74]	validation_0-mlogloss:0.48805
# [75]	validation_0-mlogloss:0.48843
# [76]	validation_0-mlogloss:0.48967
# [77]	validation_0-mlogloss:0.49107
# [78]	validation_0-mlogloss:0.49065
# [79]	validation_0-mlogloss:0.49089
# [80]	validation_0-mlogloss:0.49015
# [81]	validation_0-mlogloss:0.49140
# [82]	validation_0-mlogloss:0.49139
# [83]	validation_0-mlogloss:0.49244
# [84]	validation_0-mlogloss:0.49182
# [85]	validation_0-mlogloss:0.49121
# [86]	validation_0-mlogloss:0.49128
# [87]	validation_0-mlogloss:0.49110
# [88]	validation_0-mlogloss:0.49290
# [89]	validation_0-mlogloss:0.49429
# [90]	validation_0-mlogloss:0.49417
# [91]	validation_0-mlogloss:0.49445
# [92]	validation_0-mlogloss:0.49502
# [93]	validation_0-mlogloss:0.49465
# [94]	validation_0-mlogloss:0.49578
# [95]	validation_0-mlogloss:0.49530
# [96]	validation_0-mlogloss:0.49506
# [97]	validation_0-mlogloss:0.49529
# [98]	validation_0-mlogloss:0.49533
# [99]	validation_0-mlogloss:0.49471
# [100]	validation_0-mlogloss:0.49441
# [101]	validation_0-mlogloss:0.49407
# [102]	validation_0-mlogloss:0.49452
# [103]	validation_0-mlogloss:0.49525
# [104]	validation_0-mlogloss:0.49511
# [105]	validation_0-mlogloss:0.49532
# [106]	validation_0-mlogloss:0.49534
# [107]	validation_0-mlogloss:0.49491
# [108]	validation_0-mlogloss:0.49535
# [109]	validation_0-mlogloss:0.49573
# [110]	validation_0-mlogloss:0.49557
# [111]	validation_0-mlogloss:0.49497
# [112]	validation_0-mlogloss:0.49466
# [113]	validation_0-mlogloss:0.49422
# [114]	validation_0-mlogloss:0.49353
# [115]	validation_0-mlogloss:0.49485
# [116]	validation_0-mlogloss:0.49515
# [117]	validation_0-mlogloss:0.49532
# [118]	validation_0-mlogloss:0.49517
# [119]	validation_0-mlogloss:0.49451
# [120]	validation_0-mlogloss:0.49467
# [121]	validation_0-mlogloss:0.49374
# [122]	validation_0-mlogloss:0.49385
# [123]	validation_0-mlogloss:0.49425
# [124]	validation_0-mlogloss:0.49478
# [125]	validation_0-mlogloss:0.49536
# [126]	validation_0-mlogloss:0.49552
# [127]	validation_0-mlogloss:0.49478
# [128]	validation_0-mlogloss:0.49588
# [129]	validation_0-mlogloss:0.49594
# [130]	validation_0-mlogloss:0.49642
# [131]	validation_0-mlogloss:0.49649
# [132]	validation_0-mlogloss:0.49663
# [133]	validation_0-mlogloss:0.49738
# [134]	validation_0-mlogloss:0.49668
# [135]	validation_0-mlogloss:0.49678
# [136]	validation_0-mlogloss:0.49750
# [137]	validation_0-mlogloss:0.49644
# [138]	validation_0-mlogloss:0.49662
# [139]	validation_0-mlogloss:0.49652
# [140]	validation_0-mlogloss:0.49731
# [141]	validation_0-mlogloss:0.49777
# [142]	validation_0-mlogloss:0.49722
# [143]	validation_0-mlogloss:0.49636
# [144]	validation_0-mlogloss:0.49656
# [145]	validation_0-mlogloss:0.49668
# [146]	validation_0-mlogloss:0.49699
# [147]	validation_0-mlogloss:0.49631
# [148]	validation_0-mlogloss:0.49657
# [149]	validation_0-mlogloss:0.49716
# [150]	validation_0-mlogloss:0.49701
# [151]	validation_0-mlogloss:0.49689
# [152]	validation_0-mlogloss:0.49729
# [153]	validation_0-mlogloss:0.49778
# [154]	validation_0-mlogloss:0.49845
# [155]	validation_0-mlogloss:0.49860
# [156]	validation_0-mlogloss:0.49902
# [157]	validation_0-mlogloss:0.49923
# [158]	validation_0-mlogloss:0.49942
# [159]	validation_0-mlogloss:0.49950
# [160]	validation_0-mlogloss:0.49809
# [161]	validation_0-mlogloss:0.49892
# [162]	validation_0-mlogloss:0.49887
# [163]	validation_0-mlogloss:0.49932
# [164]	validation_0-mlogloss:0.49870
# [165]	validation_0-mlogloss:0.49843
# [166]	validation_0-mlogloss:0.49859
# [167]	validation_0-mlogloss:0.49805
# [168]	validation_0-mlogloss:0.49837
# [169]	validation_0-mlogloss:0.49963
# [170]	validation_0-mlogloss:0.49947
# [171]	validation_0-mlogloss:0.49986
# [172]	validation_0-mlogloss:0.49998
# [173]	validation_0-mlogloss:0.49943
# [174]	validation_0-mlogloss:0.49923
# [175]	validation_0-mlogloss:0.49921
# [176]	validation_0-mlogloss:0.49905
# [177]	validation_0-mlogloss:0.49899
# [178]	validation_0-mlogloss:0.49887
# [179]	validation_0-mlogloss:0.49939
# [180]	validation_0-mlogloss:0.49839
# [181]	validation_0-mlogloss:0.49883
# [182]	validation_0-mlogloss:0.49799
# [183]	validation_0-mlogloss:0.49880
# [184]	validation_0-mlogloss:0.49761
# [185]	validation_0-mlogloss:0.49792
# [186]	validation_0-mlogloss:0.49816
# [187]	validation_0-mlogloss:0.49803
# [188]	validation_0-mlogloss:0.49847
# [189]	validation_0-mlogloss:0.49795
# [190]	validation_0-mlogloss:0.49836
# [191]	validation_0-mlogloss:0.49914
# [192]	validation_0-mlogloss:0.49806
# [193]	validation_0-mlogloss:0.49821
# [194]	validation_0-mlogloss:0.49831
# [195]	validation_0-mlogloss:0.49860
# [196]	validation_0-mlogloss:0.49870
# [197]	validation_0-mlogloss:0.49846
# [198]	validation_0-mlogloss:0.49884
# [199]	validation_0-mlogloss:0.49972
# [200]	validation_0-mlogloss:0.49904
# [201]	validation_0-mlogloss:0.49927
# [202]	validation_0-mlogloss:0.49899
# [203]	validation_0-mlogloss:0.49914
# [204]	validation_0-mlogloss:0.49966
# [205]	validation_0-mlogloss:0.49968
# [206]	validation_0-mlogloss:0.50050
# [207]	validation_0-mlogloss:0.50070
# [208]	validation_0-mlogloss:0.50054
# [209]	validation_0-mlogloss:0.50007
# [210]	validation_0-mlogloss:0.50093
# [211]	validation_0-mlogloss:0.50081
# [212]	validation_0-mlogloss:0.50116
# [213]	validation_0-mlogloss:0.50127
# [214]	validation_0-mlogloss:0.50167
# [215]	validation_0-mlogloss:0.50201
# [216]	validation_0-mlogloss:0.50154
# [217]	validation_0-mlogloss:0.50196
# [218]	validation_0-mlogloss:0.50130
# [219]	validation_0-mlogloss:0.50216
# [220]	validation_0-mlogloss:0.50243
# [221]	validation_0-mlogloss:0.50224
# Stopping. Best iteration:
# [21]	validation_0-mlogloss:0.45124
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='mlogloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, objective='multi:softprob', random_state=777,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
y_pred = model.predict(X_val)
y_check = np.array(y_val)

accuracy_score(y_pred, y_check)
# Out:
# 0.8356164383561644

# %%
X_train.columns
# Out:
# Index(['sunrise', 'sunset', 'sunny', 'T_mean', 'DHI_mean', 'DNI_mean',
#        'WS_mean', 'RH_mean', 'TARGET_mean', 'temp_diff', 'GHI_mean',
#        'dew_mean'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.26369366, 0.18907659, 0.36609125, 0.05706494, 0.0123616 ,
#        0.01040507, 0.00917696, 0.01144751, 0.01923084, 0.00786069,
#        0.00844096, 0.04514994], dtype=float32)

# %%
# 모델 저장
joblib.dump(model, './model/month_xgb_200121.pkl')
# Out:
# ['./model/month_xgb_200121.pkl']

# %%
for i in range(len(y_pred)):
    
    if y_check[i] != y_pred[i]: 
        print(y_check[i]-y_pred[i], ': ', y_check[i]+1, y_pred[i]+1)
# Out:
# -1 :  6 7
# -1 :  6 7
# 1 :  3 2
# -1 :  8 9
# -1 :  6 7
# -1 :  1 2
# -1 :  8 9
# -1 :  11 12
# -11 :  1 12
# 1 :  7 6
# -1 :  6 7
# -1 :  4 5
# -5 :  4 9
# -1 :  5 6
# 10 :  11 1
# -1 :  6 7
# 1 :  7 6
# -1 :  4 5
# 1 :  5 4
# -1 :  6 7
# 1 :  3 2
# -1 :  6 7
# -1 :  10 11
# 4 :  8 4
# -1 :  7 8
# -1 :  2 3
# -11 :  1 12
# 1 :  7 6
# -1 :  10 11
# -1 :  7 8
# 1 :  7 6
# -1 :  11 12
# 1 :  5 4
# -1 :  10 11
# 1 :  8 7
# 1 :  7 6

# %% [markdown]
# #### LGBM

# %%
model = lgbm.LGBMClassifier(objective='multi:softmax', eval_metric='mlogloss', n_estimators=1000, random_state=SEED)
model.fit(X_train, y_train, eval_set=[(X_val, y_val)], early_stopping_rounds
# [272]	valid_0's multi_logloss: 0.818946
# [273]	valid_0's multi_logloss: 0.820928
# Early stopping, best iteration is:
# [73]	valid_0's multi_logloss: 0.451755
# LGBMClassifier(eval_metric='mlogloss', n_estimators=1000,
#                objective='multi:softmax', random_state=777)

# %%
y_pred = model.predict(X_val)
y_check = np.array(y_val)

accuracy_score(y_pred, y_check)
# Out:
# 0.8356164383561644

# %%
joblib.dump(model, './model/month_lgb_200121.pkl')
# Out:
# ['./model/month_lgb_200121.pkl']

# %%
for i in range(len(y_pred)):
    
    if y_check[i] != y_pred[i]: 
        print(y_check[i]-y_pred[i], ': ', y_check[i]+1, y_pred[i]+1)
# Out:
# -1 :  6 7
# 1 :  8 7
# -1 :  8 9
# -1 :  2 3
# -1 :  6 7
# -1 :  1 2
# -1 :  2 3
# -1 :  11 12
# -1 :  7 8
# 10 :  11 1
# -11 :  1 12
# -1 :  6 7
# 1 :  2 1
# -1 :  4 5
# 1 :  11 10
# -11 :  1 12
# 10 :  11 1
# -1 :  6 7
# 1 :  7 6
# -1 :  6 7
# -1 :  10 11
# -1 :  8 9
# -1 :  8 9
# -1 :  7 8
# -11 :  1 12
# 1 :  7 6
# -1 :  10 11
# -1 :  7 8
# 1 :  7 6
# -11 :  1 12
# 1 :  4 3
# 1 :  8 7
# -1 :  10 11
# -1 :  8 9
# -1 :  2 3
# 1 :  7 6

# %%
model.feature_importances_
# Out:
# array([1072,  842, 1538, 4083, 2643, 1974, 2575, 2381, 3268,  685, 1765,
#        3219])

# %%
X_train.columns
# Out:
# Index(['sunrise', 'sunset', 'sunny', 'T_mean', 'DHI_mean', 'DNI_mean',
#        'WS_mean', 'RH_mean', 'TARGET_mean', 'temp_diff', 'GHI_mean',
#        'dew_mean'],
#       dtype='object')

# %% [markdown]
# #### RF

# %%
model = RandomForestClassifier(n_estimators=1000, random_state=SEED)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=777)

# %%
y_pred = model.predict(X_val)
y_check = np.array(y_val)

accuracy_score(y_pred, y_check)
# Out:
# 0.821917808219178

# %%
for i in range(len(y_pred)):
    
    if y_check[i] != y_pred[i]: 
        print(y_check[i]-y_pred[i], ': ', y_check[i]+1, y_pred[i]+1)
# Out:
# -1 :  6 7
# -1 :  6 7
# 1 :  8 7
# -1 :  8 9
# -1 :  6 7
# -1 :  1 2
# -1 :  8 9
# -1 :  11 12
# -1 :  7 8
# -11 :  1 12
# -1 :  6 7
# 1 :  2 1
# -1 :  4 5
# 11 :  12 1
# -5 :  4 9
# -1 :  5 6
# 1 :  11 10
# 10 :  11 1
# -1 :  6 7
# 1 :  7 6
# -1 :  4 5
# -1 :  6 7
# 1 :  7 6
# -1 :  10 11
# -1 :  8 9
# -1 :  6 7
# -1 :  8 9
# -1 :  7 8
# -1 :  5 6
# -11 :  1 12
# 1 :  7 6
# 1 :  7 6
# -1 :  10 11
# -1 :  7 8
# 1 :  7 6
# 1 :  8 7
# -1 :  10 11
# -1 :  8 9
# 1 :  7 6

# %%
model.feature_importances_
# Out:
# array([0.1230732 , 0.136161  , 0.14551505, 0.1426119 , 0.06782852,
#        0.04187108, 0.04181205, 0.05357496, 0.07367155, 0.02918218,
#        0.0453983 , 0.0993002 ])
